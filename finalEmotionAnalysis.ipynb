# %%
print("Final Emotion Analysis test")
# Out:
# Final Emotion Analysis test

# %%
import string
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import nltk

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')

# Initialize the sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Read the text file
try:
    with open('read.txt', encoding='utf-8') as file:
        text = file.read()
except FileNotFoundError:
    print("File 'read.txt' not found.")
    exit()

# Convert to lower case and remove punctuation
lower_case = text.lower()
cleaned_text = lower_case.translate(str.maketrans('', '', string.punctuation))

# Tokenize words
tokenized_words = word_tokenize(cleaned_text, "english")

# Remove stop words
stop_words = set(stopwords.words('english'))
final_words = [word for word in tokenized_words if word not in stop_words]

# Load the NRC Emotion Lexicon
emotion_dict = {}
try:
    with open('NRC-Emotion-Lexicon-Wordlevel-v0.92.txt', 'r') as file:
        for line in file:
            word, emotion, is_associated = line.strip().split('\t')
            if is_associated == '1':
                if word not in emotion_dict:
                    emotion_dict[word] = []
                emotion_dict[word].append(emotion)
except FileNotFoundError:
    print("File 'NRC-Emotion-Lexicon-Wordlevel-v0.92.txt' not found.")
    exit()

# Collect emotions for words in text
emotion_list = []
for word in final_words:
    if word in emotion_dict:
        emotion_list.extend(emotion_dict[word])

# Count emotions
emotion_counts = Counter(emotion_list)
print("Emotion Counts:", emotion_counts)

# Sentiment analysis
sentiment_scores = sia.polarity_scores(text)
print("Sentiment Scores:", sentiment_scores)

# Determine sentiment category
if sentiment_scores['compound'] >= 0.05:
    sentiment_category = 'Positive'
elif sentiment_scores['compound'] <= -0.05:
    sentiment_category = 'Negative'
else:
    sentiment_category = 'Neutral'

print("Overall Sentiment:", sentiment_category)

# Plotting the emotion analysis results
fig, ax = plt.subplots()
ax.bar(emotion_counts.keys(), emotion_counts.values())
plt.xticks(rotation=45)
plt.xlabel("Emotions")
plt.ylabel("Frequency")
plt.title("Emotion Analysis from Text")
plt.tight_layout()
plt.savefig('graph.png')
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Emotion Counts: Counter({'positive': 84, 'trust': 61, 'negative': 60, 'anticipation': 46, 'joy': 44, 'fear': 39, 'sadness': 39, 'surprise': 26, 'anger': 21, 'disgust': 20})
# Sentiment Scores: {'neg': 0.091, 'neu': 0.746, 'pos': 0.163, 'compound': 0.9996}
# Overall Sentiment: Positive

# %%
#positive test final
import string
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import nltk

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')

# Initialize the sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Read the text file
try:
    with open('positive.txt', encoding='utf-8') as file:
        text = file.read()
except FileNotFoundError:
    print("File 'positive.txt' not found.")
    exit()

# Convert to lower case and remove punctuation
lower_case = text.lower()
cleaned_text = lower_case.translate(str.maketrans('', '', string.punctuation))

# Tokenize words
tokenized_words = word_tokenize(cleaned_text, "english")

# Remove stop words
stop_words = set(stopwords.words('english'))
final_words = [word for word in tokenized_words if word not in stop_words]

# Load the NRC Emotion Lexicon
emotion_dict = {}
try:
    with open('NRC-Emotion-Lexicon-Wordlevel-v0.92.txt', 'r') as file:
        for line in file:
            word, emotion, is_associated = line.strip().split('\t')
            if is_associated == '1':
                if word not in emotion_dict:
                    emotion_dict[word] = []
                emotion_dict[word].append(emotion)
except FileNotFoundError:
    print("File 'NRC-Emotion-Lexicon-Wordlevel-v0.92.txt' not found.")
    exit()

# Collect emotions for words in text
emotion_list = []
for word in final_words:
    if word in emotion_dict:
        emotion_list.extend(emotion_dict[word])

# Count emotions
emotion_counts = Counter(emotion_list)
print("Emotion Counts:", emotion_counts)

# Sentiment analysis
sentiment_scores = sia.polarity_scores(text)
print("Sentiment Scores:", sentiment_scores)

# Determine sentiment category
if sentiment_scores['compound'] >= 0.05:
    sentiment_category = 'Positive'
elif sentiment_scores['compound'] <= -0.05:
    sentiment_category = 'Negative'
else:
    sentiment_category = 'Neutral'

print("Overall Sentiment:", sentiment_category)

# Plotting the emotion analysis results
fig, ax = plt.subplots()
ax.bar(emotion_counts.keys(), emotion_counts.values())
plt.xticks(rotation=45)
plt.xlabel("Emotions")
plt.ylabel("Frequency")
plt.title("Emotion Analysis from Text")
plt.tight_layout()
plt.savefig('PositiveGraph.png')
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Emotion Counts: Counter({'positive': 136, 'trust': 53, 'joy': 32, 'anticipation': 26, 'negative': 9, 'surprise': 7, 'fear': 6, 'anger': 3, 'disgust': 2, 'sadness': 1})
# Sentiment Scores: {'neg': 0.014, 'neu': 0.786, 'pos': 0.2, 'compound': 0.9998}
# Overall Sentiment: Positive

# %%
#Negative test final
import string
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import nltk

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')

# Initialize the sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Read the text file
try:
    with open('negative.txt', encoding='utf-8') as file:
        text = file.read()
except FileNotFoundError:
    print("File 'negative.txt' not found.")
    exit()

# Convert to lower case and remove punctuation
lower_case = text.lower()
cleaned_text = lower_case.translate(str.maketrans('', '', string.punctuation))

# Tokenize words
tokenized_words = word_tokenize(cleaned_text, "english")

# Remove stop words
stop_words = set(stopwords.words('english'))
final_words = [word for word in tokenized_words if word not in stop_words]

# Load the NRC Emotion Lexicon
emotion_dict = {}
try:
    with open('NRC-Emotion-Lexicon-Wordlevel-v0.92.txt', 'r') as file:
        for line in file:
            word, emotion, is_associated = line.strip().split('\t')
            if is_associated == '1':
                if word not in emotion_dict:
                    emotion_dict[word] = []
                emotion_dict[word].append(emotion)
except FileNotFoundError:
    print("File 'NRC-Emotion-Lexicon-Wordlevel-v0.92.txt' not found.")
    exit()

# Collect emotions for words in text
emotion_list = []
for word in final_words:
    if word in emotion_dict:
        emotion_list.extend(emotion_dict[word])

# Count emotions
emotion_counts = Counter(emotion_list)
print("Emotion Counts:", emotion_counts)

# Sentiment analysis
sentiment_scores = sia.polarity_scores(text)
print("Sentiment Scores:", sentiment_scores)

# Determine sentiment category
if sentiment_scores['compound'] >= 0.05:
    sentiment_category = 'Positive'
elif sentiment_scores['compound'] <= -0.05:
    sentiment_category = 'Negative'
else:
    sentiment_category = 'Neutral'

print("Overall Sentiment:", sentiment_category)

# Plotting the emotion analysis results
fig, ax = plt.subplots()
ax.bar(emotion_counts.keys(), emotion_counts.values())
plt.xticks(rotation=45)
plt.xlabel("Emotions")
plt.ylabel("Frequency")
plt.title("Emotion Analysis from Text")
plt.tight_layout()
plt.savefig('NegativeGraph.png')
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Emotion Counts: Counter({'positive': 77, 'negative': 58, 'trust': 35, 'anticipation': 26, 'fear': 25, 'sadness': 18, 'anger': 17, 'surprise': 10, 'disgust': 8, 'joy': 7})
# Sentiment Scores: {'neg': 0.16, 'neu': 0.682, 'pos': 0.157, 'compound': -0.8568}
# Overall Sentiment: Negative

# %%
#mixed test final
import string
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import nltk

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')

# Initialize the sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Read the text file
try:
    with open('mixed.txt', encoding='utf-8') as file:
        text = file.read()
except FileNotFoundError:
    print("File 'mixed.txt' not found.")
    exit()

# Convert to lower case and remove punctuation
lower_case = text.lower()
cleaned_text = lower_case.translate(str.maketrans('', '', string.punctuation))

# Tokenize words
tokenized_words = word_tokenize(cleaned_text, "english")

# Remove stop words
stop_words = set(stopwords.words('english'))
final_words = [word for word in tokenized_words if word not in stop_words]

# Load the NRC Emotion Lexicon
emotion_dict = {}
try:
    with open('NRC-Emotion-Lexicon-Wordlevel-v0.92.txt', 'r') as file:
        for line in file:
            word, emotion, is_associated = line.strip().split('\t')
            if is_associated == '1':
                if word not in emotion_dict:
                    emotion_dict[word] = []
                emotion_dict[word].append(emotion)
except FileNotFoundError:
    print("File 'NRC-Emotion-Lexicon-Wordlevel-v0.92.txt' not found.")
    exit()

# Collect emotions for words in text
emotion_list = []
for word in final_words:
    if word in emotion_dict:
        emotion_list.extend(emotion_dict[word])

# Count emotions
emotion_counts = Counter(emotion_list)
print("Emotion Counts:", emotion_counts)

# Sentiment analysis
sentiment_scores = sia.polarity_scores(text)
print("Sentiment Scores:", sentiment_scores)

# Determine sentiment category
if sentiment_scores['compound'] >= 0.05:
    sentiment_category = 'Positive'
elif sentiment_scores['compound'] <= -0.05:
    sentiment_category = 'Negative'
else:
    sentiment_category = 'Neutral'

print("Overall Sentiment:", sentiment_category)

# Plotting the emotion analysis results
fig, ax = plt.subplots()
ax.bar(emotion_counts.keys(), emotion_counts.values())
plt.xticks(rotation=45)
plt.xlabel("Emotions")
plt.ylabel("Frequency")
plt.title("Emotion Analysis from Text")
plt.tight_layout()
plt.savefig('MixedGraph.png')
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Emotion Counts: Counter({'positive': 79, 'trust': 27, 'anticipation': 15, 'negative': 9, 'joy': 8, 'surprise': 4, 'fear': 3, 'anger': 2})
# Sentiment Scores: {'neg': 0.058, 'neu': 0.789, 'pos': 0.153, 'compound': 0.9966}
# Overall Sentiment: Positive
